# %%
from src.spectral_sensor import SpectralSensor

sensor1 = SpectralSensor("/dev/cu.wchusbserial10")
# Out:
# INFO:root:Configuring spectral sensor board serial port..
# INFO:root:Attempting to open spectral sensor board serial port..
# INFO:root:Build:Mar 27 2021
# INFO:root:rst:0x1 (POWERON),boot:0x8 (SPI_FAST_FLASH_BOOT)
# INFO:root:SPIWP:0xee
# INFO:root:mode:DIO, clock div:1
# INFO:root:load:0x3fce3808,len:0x41c
# INFO:root:load:0x403c9700,len:0x9a8
# INFO:root:load:0x403cc700,len:0x28ac
# INFO:root:entry 0x403c98b8
# INFO:root:[   109][I][esp32-hal-i2c.c:75] i2cInit(): Initialising I2C Master: sda=8 scl=9 freq=100000
# INFO:root:**Available functions**
# INFO:root:Signals:
# INFO:root:setHeaterPower(int heater, int power)
# INFO:root:setVoltage(float volts) 0-10V
# INFO:root:setCurrent(float mA) 0-20mA
# INFO:root:Sensors:
# INFO:root:readSensor(int sensor)
# INFO:root:fullShutdown()
# INFO:root:wakeAll()
# INFO:root:Serial connection to spectral sensor board established.

# %%
for i in range(1,16):
    data = sensor1.read_sensor(i)
    print(data)
# Out:
# [ 20141][W][Wire.cpp:301] begin(): Bus already started in Master Mode.
# F1=1,F2=5,F3=6,F4=12,F5=17,F6=25,F7=35,F8=32,CLR=84,NIR=5
# #
# [ 20439][W][Wire.cpp:301] begin(): Bus already started in Master Mode.
# F1=1,F2=5,F3=6,F4=11,F5=16,F6=23,F7=35,F8=31,CLR=6,NIR=0
# #
# [ 20737][W][Wire.cpp:301] begin(): Bus already started in Master Mode.
# F1=1,F2=5,F3=8,F4=13,F5=18,F6=24,F7=39,F8=33,CLR=86,NIR=5
# #
# [ 21034][W][Wire.cpp:301] begin(): Bus already started in Master Mode.
# F1=1,F2=5,F3=6,F4=11,F5=14,F6=22,F7=31,F8=31,CLR=3,NIR=0
# #
# [ 21332][W][Wire.cpp:301] begin(): Bus already started in Master Mode.
# F1=1,F2=5,F3=7,F4=13,F5=18,F6=25,F7=38,F8=31,CLR=89,NIR=5
# #
